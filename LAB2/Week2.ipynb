# %% [markdown]
# <a href="https://colab.research.google.com/github/NateMophi/NLP-SCC-453/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/UCREL/web-corpus-construction.git
# Out:
# Cloning into 'web-corpus-construction'...
# remote: Enumerating objects: 262, done.
# remote: Total 262 (delta 0), reused 0 (delta 0), pack-reused 262 (from 1)
# Receiving objects: 100% (262/262), 2.76 MiB | 9.64 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# %cd /content/web-corpus-construction/
# Out:
# /content/web-corpus-construction

# %%
# !git remote rename origin upstream

# %%
# !git remote add origin https://github.com/NateMophi/NLP-SCC-453.git

# %%
# !./spider.py -h
# Out:
# /content/web-corpus-construction/./spider.py:68: SyntaxWarning: invalid escape sequence '\/'
#   MetadataRegexpFilter.MetadataRegexpFilter('content_type', 'text\/(x?html|plain)'),   # Content type
# /content/web-corpus-construction/Features.py:111: SyntaxWarning: invalid escape sequence '\w'
#   charset = re.findall("charset=[-\w]*", content_type)[0].split("=")[1]
# /content/web-corpus-construction/Normalisation.py:55: SyntaxWarning: invalid escape sequence '\?'
#   url = re.sub('\?utm_source=feedburner.+$', '', url)
# usage: spider.py [-h] [-seeds LIST] [-db DBDIR] [-loglevel LOGLEVEL]
#
# A web crawler demo for the UCREL Summer School 2016
#
# options:
#   -h, --help          show this help message and exit
#   -seeds LIST
#   -db DBDIR
#   -loglevel LOGLEVEL

# %%
# !./spider.py -seeds seed_urls/twitter.txt -db output -loglevel DEBUG
# Out:
# Streaming output truncated to the last 5000 lines.
#   DEBUG - features: Normalised URL: https://trumpwhitehouse.archives.gov/issues/healthcare/ -> https://trumpwhitehouse.archives.gov/issues/healthcare/
#   DEBUG - features: Adding URL to candidate list: https://trumpwhitehouse.archives.gov/issues/healthcare/
#   DEBUG - features: Normalised URL: https://trumpwhitehouse.archives.gov/issues/ -> https://trumpwhitehouse.archives.gov/issues/
#   DEBUG - features: Adding URL to candidate list: https://trumpwhitehouse.archives.gov/issues/
#   DEBUG - features: Normalised URL: https://trumpwhitehouse.archives.gov/the-trump-administration/ -> https://trumpwhitehouse.archives.gov/the-trump-administration/
#   DEBUG - features: Adding URL to candidate list: https://trumpwhitehouse.archives.gov/the-trump-administration/
#   DEBUG - features: Normalised URL: https://trumpwhitehouse.archives.gov/people/donald-j-trump/ -> https://trumpwhitehouse.archives.gov/people/donald-j-trump/
# ...

# %%
# !./spider.py -db output -loglevel DEBUG
# Out:
# /content/web-corpus-construction/./spider.py:68: SyntaxWarning: invalid escape sequence '\/'
#   MetadataRegexpFilter.MetadataRegexpFilter('content_type', 'text\/(x?html|plain)'),   # Content type
#    INFO - storage : Using output database at output
#   DEBUG - storage : SQL: select count(*) from output;
#   DEBUG - storage : SQL: select count(*) from `urls` where downloaded = ?;
#    INFO - main    : 101 URLs downloaded; 1061 available
#   DEBUG - storage : SQL: select url, id, goodness, depth from urls where downloaded = ? order by goodness DESC limit 1;
#    INFO - main    : URL chosen -- goodness: 87, depth: 8
#   DEBUG - storage : SQL: UPDATE `urls` SET downloaded = 1 WHERE id = ?;
#    INFO - main    : Retrieving https://trumpwhitehouse.archives.gov/presidential-actions/executive-order-protecting-vulnerable-newborn-infant-children/...
#   DEBUG - spider  : Read 4096 bytes (max: 20971520)
#   DEBUG - spider  : Read 8192 bytes (max: 20971520)
# ...

# %%
# !pip install --user -r requirements.txt

# %%
# !git add .

# %%
# !git config --global user.email "mopefaniran@gmail.com"
# !git config --global user.name "Eyimofe Ope-Faniran"

# %%
# !git commit -m"Init Commit"
# Out:
# [master ff2c77e] Init Commit
#  103 files changed, 88213 insertions(+)
#  create mode 100644 output/1005.html
#  create mode 100644 output/1095.html
#  create mode 100644 output/1100.html
#  create mode 100644 output/1124.html
#  create mode 100644 output/1145.html
#  create mode 100644 output/1146.html
#  create mode 100644 output/1151.html
#  create mode 100644 output/1152.html
#  create mode 100644 output/116.html
#  create mode 100644 output/1182.html
#  create mode 100644 output/1183.html
#  create mode 100644 output/1184.html
#  create mode 100644 output/1185.html
#  create mode 100644 output/1187.html
#  create mode 100644 output/1189.html
#  create mode 100644 output/1234.html
#  create mode 100644 output/184.html
#  create mode 100644 output/185.html
#  create mode 100644 output/187.html
#  create mode 100644 output/189.html
#  create mode 100644 output/190.html
#  create mode 100644 output/201.html
#  create mode 100644 output/203.html
#  create mode 100644 output/204.html
# ...

# %%
# !git push
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/NateMophi/NLP-SCC-453.git'

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'upstream/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
